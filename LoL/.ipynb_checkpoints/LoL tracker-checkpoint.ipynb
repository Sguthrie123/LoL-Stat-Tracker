# %% [markdown]
# # Import Dependencies

# %%
import json 
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import pprint
from config import api_key

# %% [markdown]
# # Get the specfic user ranked status
#
# #### Must

# %%
# https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/
# WhatBrownies?api_key=RGAPI-e7acc99f-5037-4f32-9af5-ca038cea3485

# Change username to find specfic user
username = 'WhatBrownies'    
URL = 'https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/'
region = 'na1'

# Query URL
query_url = f'{URL}{username}?api_key={api_key}'
query_url

response = requests.get(query_url).json()
pprint.pprint(response)
summonerid = response['id']
accountid = response['accountId']
accountid
summonerid
# Out:
# {'accountId': '6qvWHdHTqDozay5XNscxbmJgSx3NEOEmLUUj-Jg4QpL8NDs',
#  'id': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#  'name': 'WhatBrownies',
#  'profileIconId': 983,
#  'puuid': '4CYuHNdagN3QZDH3Pthdmx0v77uovFHmmV-mglRPzLSfPSyEpbig_HB1oxuyiXGQnz5KJ2vEcNX5FA',
#  'revisionDate': 1586244246000,
#  'summonerLevel': 161}
# 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU'

# %% [markdown]
# # Get User recent games
#
# #### Must user users account ID from previous cell

# %%
lane = []
champion = []
role = []
season = []

games_url = 'https://na1.api.riotgames.com/lol/match/v4/matchlists/by-account/'

games_query_url = f'{games_url}{accountid}?api_key={api_key}'

recent_games = requests.get(games_query_url).json()
pprint.pprint(recent_games)

# print(recent_games['matches'][0]['champion'])
# Out:
# {'endIndex': 100,
#  'matches': [{'champion': 57,
#               'gameId': 3364474848,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1586242173824},
#              {'champion': 33,
#               'gameId': 3364389663,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1586240067866},
#              {'champion': 53,
#               'gameId': 3364365574,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1586238496643},
#              {'champion': 350,
#               'gameId': 3364309436,
#               'lane': 'JUNGLE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'NONE',
#               'season': 13,
#               'timestamp': 1586236692287},
#              {'champion': 54,
#               'gameId': 3360816041,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1586056800784},
#              {'champion': 875,
#               'gameId': 3360786940,
#               'lane': 'JUNGLE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'NONE',
#               'season': 13,
#               'timestamp': 1586054927426},
#              {'champion': 53,
#               'gameId': 3360717479,
#               'lane': 'JUNGLE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'NONE',
#               'season': 13,
#               'timestamp': 1586052649481},
#              {'champion': 64,
#               'gameId': 3360648778,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1586050439201},
#              {'champion': 223,
#               'gameId': 3360625328,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1586049312690},
#              {'champion': 25,
#               'gameId': 3357300958,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1585881230081},
#              {'champion': 201,
#               'gameId': 3357261303,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1585879075538},
#              {'champion': 267,
#               'gameId': 3357211383,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1585876620224},
#              {'champion': 86,
#               'gameId': 3357105085,
#               'lane': 'JUNGLE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'NONE',
#               'season': 13,
#               'timestamp': 1585874775013},
#              {'champion': 9,
#               'gameId': 3357025236,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1585871993335},
#              {'champion': 35,
#               'gameId': 3356977680,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1585869711413},
#              {'champion': 429,
#               'gameId': 3353895383,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 420,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1585715407972},
#              {'champion': 429,
#               'gameId': 3353765969,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 420,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1585710759726},
#              {'champion': 142,
#               'gameId': 3348335077,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1585448754956},
#              {'champion': 161,
#               'gameId': 3348276561,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1585446916630},
#              {'champion': 53,
#               'gameId': 3348319972,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1585445594275},
#              {'champion': 432,
#               'gameId': 3348212773,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1585443607818},
#              {'champion': 27,
#               'gameId': 3348125375,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1585441624075},
#              {'champion': 35,
#               'gameId': 3348071826,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1585438015160},
#              {'champion': 35,
#               'gameId': 3347985047,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1585435931748},
#              {'champion': 101,
#               'gameId': 3347956037,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1585433687882},
#              {'champion': 82,
#               'gameId': 3347951945,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1585432527439},
#              {'champion': 9,
#               'gameId': 3347856877,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1585430902599},
#              {'champion': 80,
#               'gameId': 3347826975,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1585428392736},
#              {'champion': 154,
#               'gameId': 3346848368,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1585379482476},
#              {'champion': 57,
#               'gameId': 3346851459,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1585377388252},
#              {'champion': 54,
#               'gameId': 3346737893,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1585376013153},
#              {'champion': 33,
#               'gameId': 3346723741,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1585374862412},
#              {'champion': 33,
#               'gameId': 3346659318,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1585373759429},
#              {'champion': 154,
#               'gameId': 3346082588,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1585352047341},
#              {'champion': 350,
#               'gameId': 3345954174,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1585349362076},
#              {'champion': 98,
#               'gameId': 3345889328,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1585347948086},
#              {'champion': 89,
#               'gameId': 3345882198,
#               'lane': 'JUNGLE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'NONE',
#               'season': 13,
#               'timestamp': 1585345848632},
#              {'champion': 26,
#               'gameId': 3345818875,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1585344876315},
#              {'champion': 64,
#               'gameId': 3345815236,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1585343779398},
#              {'champion': 161,
#               'gameId': 3345831146,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1585342662673},
#              {'champion': 34,
#               'gameId': 3345785956,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 1020,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1585341161594},
#              {'champion': 498,
#               'gameId': 3338042123,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 420,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584942511798},
#              {'champion': 51,
#               'gameId': 3337972906,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 420,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1584939858122},
#              {'champion': 429,
#               'gameId': 3337943348,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 420,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1584937621022},
#              {'champion': 429,
#               'gameId': 3337896428,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 420,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1584935998758},
#              {'champion': 498,
#               'gameId': 3335749059,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584844559614},
#              {'champion': 222,
#               'gameId': 3335780476,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584842542880},
#              {'champion': 432,
#               'gameId': 3335672592,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1584840480752},
#              {'champion': 67,
#               'gameId': 3335612251,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584837782872},
#              {'champion': 429,
#               'gameId': 3335523051,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584835111037},
#              {'champion': 498,
#               'gameId': 3335463522,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584832319250},
#              {'champion': 350,
#               'gameId': 3335423014,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1584829134392},
#              {'champion': 412,
#               'gameId': 3335376516,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1584827484311},
#              {'champion': 202,
#               'gameId': 3335268270,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584824630224},
#              {'champion': 103,
#               'gameId': 3334600692,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 450,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584772083768},
#              {'champion': 236,
#               'gameId': 3334497243,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 450,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584770694703},
#              {'champion': 86,
#               'gameId': 3327304347,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1584406083860},
#              {'champion': 6,
#               'gameId': 3327285687,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1584403945732},
#              {'champion': 150,
#               'gameId': 3326283494,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 450,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1584331119178},
#              {'champion': 498,
#               'gameId': 3326223285,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 700,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584328613077},
#              {'champion': 202,
#               'gameId': 3326144892,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 700,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584325826535},
#              {'champion': 498,
#               'gameId': 3326100887,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 700,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584322358154},
#              {'champion': 498,
#               'gameId': 3325929816,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584314744608},
#              {'champion': 429,
#               'gameId': 3325839118,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584311234613},
#              {'champion': 86,
#               'gameId': 3325221145,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1584246717862},
#              {'champion': 412,
#               'gameId': 3325147354,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 450,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1584245095605},
#              {'champion': 51,
#               'gameId': 3324999384,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 700,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584240582941},
#              {'champion': 202,
#               'gameId': 3324817256,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 700,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584237267510},
#              {'champion': 222,
#               'gameId': 3324639264,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 700,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584234228332},
#              {'champion': 202,
#               'gameId': 3324441248,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584217337242},
#              {'champion': 51,
#               'gameId': 3324343253,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584213378728},
#              {'champion': 202,
#               'gameId': 3324309090,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584211625639},
#              {'champion': 81,
#               'gameId': 3324274398,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584208826391},
#              {'champion': 202,
#               'gameId': 3324252053,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1584202828644},
#              {'champion': 86,
#               'gameId': 3324015265,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1584167216320},
#              {'champion': 223,
#               'gameId': 3323970322,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1584164471813},
#              {'champion': 202,
#               'gameId': 3323898353,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584160798085},
#              {'champion': 21,
#               'gameId': 3323851346,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584158055606},
#              {'champion': 202,
#               'gameId': 3323819843,
#               'lane': 'BOTTOM',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1584154942477},
#              {'champion': 134,
#               'gameId': 3323467623,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1584135502572},
#              {'champion': 157,
#               'gameId': 3323452087,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1584132845875},
#              {'champion': 412,
#               'gameId': 3323409045,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 450,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1584131249889},
#              {'champion': 86,
#               'gameId': 3322616311,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1584069356365},
#              {'champion': 86,
#               'gameId': 3322649770,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1584067644532},
#              {'champion': 39,
#               'gameId': 3322576042,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1584066273613},
#              {'champion': 142,
#               'gameId': 3318120657,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1583641529138},
#              {'champion': 86,
#               'gameId': 3315434210,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1583389035445},
#              {'champion': 86,
#               'gameId': 3315460197,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1583387239676},
#              {'champion': 86,
#               'gameId': 3315180055,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1583372478063},
#              {'champion': 86,
#               'gameId': 3315123176,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'DUO',
#               'season': 13,
#               'timestamp': 1583369738126},
#              {'champion': 238,
#               'gameId': 3314275018,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1583295366345},
#              {'champion': 157,
#               'gameId': 3314238428,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 400,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1583293685882},
#              {'champion': 103,
#               'gameId': 3313222647,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1583206537228},
#              {'champion': 157,
#               'gameId': 3313136693,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 440,
#               'role': 'SOLO',
#               'season': 13,
#               'timestamp': 1583203711733},
#              {'champion': 89,
#               'gameId': 3310571271,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 450,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1582963012825},
#              {'champion': 412,
#               'gameId': 3310536748,
#               'lane': 'TOP',
#               'platformId': 'NA1',
#               'queue': 450,
#               'role': 'DUO_CARRY',
#               'season': 13,
#               'timestamp': 1582961151918},
#              {'champion': 55,
#               'gameId': 3310541906,
#               'lane': 'JUNGLE',
#               'platformId': 'NA1',
#               'queue': 450,
#               'role': 'NONE',
#               'season': 13,
#               'timestamp': 1582959314019},
#              {'champion': 39,
#               'gameId': 3310488976,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 450,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1582958063911},
#              {'champion': 76,
#               'gameId': 3310458235,
#               'lane': 'NONE',
#               'platformId': 'NA1',
#               'queue': 450,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1582956969149},
#              {'champion': 134,
#               'gameId': 3306155912,
#               'lane': 'MID',
#               'platformId': 'NA1',
#               'queue': 450,
#               'role': 'DUO_SUPPORT',
#               'season': 13,
#               'timestamp': 1582522587055}],
#  'startIndex': 0,
#  'totalGames': 152}

# %% [markdown]
# # Create a table for user with information of most recent games

# %%
number_of_games = recent_games['endIndex']
for i in range(number_of_games): 
    champion.append(recent_games['matches'][i]['champion'])
    lane.append(recent_games['matches'][i]['lane'])
    role.append(recent_games['matches'][i]['role'])
    season.append(recent_games['matches'][i]['season'])
      
      
user_dict = {
    'Champion': champion, 
    'Lane' : lane, 
    'Role' : role,
    'Season' : season
}



user_df = pd.DataFrame(data=user_dict)
user_df.count()
# Out:
# Champion    100
# Lane        100
# Role        100
# Season      100
# dtype: int64

# %%
user_df
# Out:
#     Champion    Lane         Role  Season
# 0         57  BOTTOM          DUO      13
# 1         33     TOP    DUO_CARRY      13
# 2         53    NONE  DUO_SUPPORT      13
# 3        350  JUNGLE         NONE      13
# 4         54     TOP          DUO      13
# ..       ...     ...          ...     ...
# 95       412     TOP    DUO_CARRY      13
# 96        55  JUNGLE         NONE      13
# 97        39    NONE  DUO_SUPPORT      13
# 98        76    NONE  DUO_SUPPORT      13
# 99       134     MID  DUO_SUPPORT      13
#
# [100 rows x 4 columns]

# %% [markdown]
# # Create Number of games per lane for user

# %%
user_df['Lane'].value_counts().plot.barh()
plt.xlabel('Number of Games')
plt.ylabel('Lane')
plt.title('Number of Games per Lane')
# Out:
# Text(0.5, 1.0, 'Number of Games per Lane')

# %% [markdown]
# # Create number of Games per Role

# %%
user_df['Role'].value_counts().plot.barh()
plt.xlabel('Number of Games')
plt.ylabel('Role')
plt.title('Number of Games per Role')
# Out:
# Text(0.5, 1.0, 'Number of Games per Role')

# %% [markdown]
# # Champion Mastery

# %%
championMastery_url = f'https://{region}.api.riotgames.com/lol/champion-mastery/v4/champion-masteries/by-summoner/{summonerid}?api_key={api_key}'
championMastery = requests.get(championMastery_url).json()
pprint.pprint(championMastery)
# Out:
# [{'championId': 222,
#   'championLevel': 7,
#   'championPoints': 458294,
#   'championPointsSinceLastLevel': 436694,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'lastPlayTime': 1584844010000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 412,
#   'championLevel': 7,
#   'championPoints': 309058,
#   'championPointsSinceLastLevel': 287458,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'lastPlayTime': 1584828901000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 236,
#   'championLevel': 7,
#   'championPoints': 95742,
#   'championPointsSinceLastLevel': 74142,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'lastPlayTime': 1584771943000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 51,
#   'championLevel': 6,
#   'championPoints': 55800,
#   'championPointsSinceLastLevel': 34200,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'lastPlayTime': 1584942094000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 1},
#  {'championId': 103,
#   'championLevel': 6,
#   'championPoints': 55084,
#   'championPointsSinceLastLevel': 33484,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'lastPlayTime': 1584773420000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 67,
#   'championLevel': 6,
#   'championPoints': 53834,
#   'championPointsSinceLastLevel': 32234,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'lastPlayTime': 1584840186000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 1},
#  {'championId': 202,
#   'championLevel': 6,
#   'championPoints': 39947,
#   'championPointsSinceLastLevel': 18347,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'lastPlayTime': 1584826952000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 1},
#  {'championId': 157,
#   'championLevel': 6,
#   'championPoints': 36489,
#   'championPointsSinceLastLevel': 14889,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'lastPlayTime': 1584135042000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 53,
#   'championLevel': 5,
#   'championPoints': 35434,
#   'championPointsSinceLastLevel': 13834,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'lastPlayTime': 1586239458000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 1},
#  {'championId': 15,
#   'championLevel': 6,
#   'championPoints': 34421,
#   'championPointsSinceLastLevel': 12821,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'lastPlayTime': 1575678532000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 79,
#   'championLevel': 6,
#   'championPoints': 31880,
#   'championPointsSinceLastLevel': 10280,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'lastPlayTime': 1574588924000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 1},
#  {'championId': 81,
#   'championLevel': 5,
#   'championPoints': 29547,
#   'championPointsSinceLastLevel': 7947,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'lastPlayTime': 1584210854000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 21,
#   'championLevel': 5,
#   'championPoints': 28555,
#   'championPointsSinceLastLevel': 6955,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'lastPlayTime': 1584160538000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 89,
#   'championLevel': 5,
#   'championPoints': 25486,
#   'championPointsSinceLastLevel': 3886,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'lastPlayTime': 1585347721000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 1},
#  {'championId': 25,
#   'championLevel': 5,
#   'championPoints': 23925,
#   'championPointsSinceLastLevel': 2325,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'lastPlayTime': 1585882436000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 1},
#  {'championId': 64,
#   'championLevel': 5,
#   'championPoints': 21693,
#   'championPointsSinceLastLevel': 93,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'lastPlayTime': 1586052236000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 114,
#   'championLevel': 4,
#   'championPoints': 19897,
#   'championPointsSinceLastLevel': 7297,
#   'championPointsUntilNextLevel': 1703,
#   'chestGranted': False,
#   'lastPlayTime': 1576218292000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 145,
#   'championLevel': 4,
#   'championPoints': 18710,
#   'championPointsSinceLastLevel': 6110,
#   'championPointsUntilNextLevel': 2890,
#   'chestGranted': False,
#   'lastPlayTime': 1582410358000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 7,
#   'championLevel': 4,
#   'championPoints': 16838,
#   'championPointsSinceLastLevel': 4238,
#   'championPointsUntilNextLevel': 4762,
#   'chestGranted': False,
#   'lastPlayTime': 1570240564000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 238,
#   'championLevel': 4,
#   'championPoints': 16053,
#   'championPointsSinceLastLevel': 3453,
#   'championPointsUntilNextLevel': 5547,
#   'chestGranted': False,
#   'lastPlayTime': 1583297847000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 76,
#   'championLevel': 4,
#   'championPoints': 15446,
#   'championPointsSinceLastLevel': 2846,
#   'championPointsUntilNextLevel': 6154,
#   'chestGranted': True,
#   'lastPlayTime': 1582957761000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 161,
#   'championLevel': 4,
#   'championPoints': 15071,
#   'championPointsSinceLastLevel': 2471,
#   'championPointsUntilNextLevel': 6529,
#   'chestGranted': False,
#   'lastPlayTime': 1585448553000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 201,
#   'championLevel': 4,
#   'championPoints': 14628,
#   'championPointsSinceLastLevel': 2028,
#   'championPointsUntilNextLevel': 6972,
#   'chestGranted': False,
#   'lastPlayTime': 1585880851000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 498,
#   'championLevel': 4,
#   'championPoints': 13927,
#   'championPointsSinceLastLevel': 1327,
#   'championPointsUntilNextLevel': 7673,
#   'chestGranted': False,
#   'lastPlayTime': 1584944823000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 63,
#   'championLevel': 4,
#   'championPoints': 13221,
#   'championPointsSinceLastLevel': 621,
#   'championPointsUntilNextLevel': 8379,
#   'chestGranted': False,
#   'lastPlayTime': 1522286818000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 432,
#   'championLevel': 3,
#   'championPoints': 12417,
#   'championPointsSinceLastLevel': 6417,
#   'championPointsUntilNextLevel': 183,
#   'chestGranted': False,
#   'lastPlayTime': 1585445240000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 16,
#   'championLevel': 3,
#   'championPoints': 11868,
#   'championPointsSinceLastLevel': 5868,
#   'championPointsUntilNextLevel': 732,
#   'chestGranted': False,
#   'lastPlayTime': 1560719245000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 39,
#   'championLevel': 3,
#   'championPoints': 11499,
#   'championPointsSinceLastLevel': 5499,
#   'championPointsUntilNextLevel': 1101,
#   'chestGranted': False,
#   'lastPlayTime': 1584067310000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 429,
#   'championLevel': 3,
#   'championPoints': 11145,
#   'championPointsSinceLastLevel': 5145,
#   'championPointsUntilNextLevel': 1455,
#   'chestGranted': True,
#   'lastPlayTime': 1585717286000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 115,
#   'championLevel': 3,
#   'championPoints': 10879,
#   'championPointsSinceLastLevel': 4879,
#   'championPointsUntilNextLevel': 1721,
#   'chestGranted': False,
#   'lastPlayTime': 1579675857000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 34,
#   'championLevel': 3,
#   'championPoints': 10813,
#   'championPointsSinceLastLevel': 4813,
#   'championPointsUntilNextLevel': 1787,
#   'chestGranted': False,
#   'lastPlayTime': 1585342053000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 22,
#   'championLevel': 3,
#   'championPoints': 10653,
#   'championPointsSinceLastLevel': 4653,
#   'championPointsUntilNextLevel': 1947,
#   'chestGranted': False,
#   'lastPlayTime': 1580532962000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 497,
#   'championLevel': 3,
#   'championPoints': 10603,
#   'championPointsSinceLastLevel': 4603,
#   'championPointsUntilNextLevel': 1997,
#   'chestGranted': False,
#   'lastPlayTime': 1576215356000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 142,
#   'championLevel': 3,
#   'championPoints': 10289,
#   'championPointsSinceLastLevel': 4289,
#   'championPointsUntilNextLevel': 2311,
#   'chestGranted': False,
#   'lastPlayTime': 1585449842000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 86,
#   'championLevel': 3,
#   'championPoints': 9898,
#   'championPointsSinceLastLevel': 3898,
#   'championPointsUntilNextLevel': 2702,
#   'chestGranted': True,
#   'lastPlayTime': 1585876396000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 18,
#   'championLevel': 3,
#   'championPoints': 9828,
#   'championPointsSinceLastLevel': 3828,
#   'championPointsUntilNextLevel': 2772,
#   'chestGranted': False,
#   'lastPlayTime': 1570260053000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 150,
#   'championLevel': 3,
#   'championPoints': 9577,
#   'championPointsSinceLastLevel': 3577,
#   'championPointsUntilNextLevel': 3023,
#   'chestGranted': True,
#   'lastPlayTime': 1584332695000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 92,
#   'championLevel': 3,
#   'championPoints': 8210,
#   'championPointsSinceLastLevel': 2210,
#   'championPointsUntilNextLevel': 4390,
#   'chestGranted': False,
#   'lastPlayTime': 1576910344000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 59,
#   'championLevel': 3,
#   'championPoints': 7759,
#   'championPointsSinceLastLevel': 1759,
#   'championPointsUntilNextLevel': 4841,
#   'chestGranted': False,
#   'lastPlayTime': 1574404098000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 99,
#   'championLevel': 3,
#   'championPoints': 7548,
#   'championPointsSinceLastLevel': 1548,
#   'championPointsUntilNextLevel': 5052,
#   'chestGranted': False,
#   'lastPlayTime': 1580106142000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 1,
#   'championLevel': 3,
#   'championPoints': 7022,
#   'championPointsSinceLastLevel': 1022,
#   'championPointsUntilNextLevel': 5578,
#   'chestGranted': False,
#   'lastPlayTime': 1575612802000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 33,
#   'championLevel': 3,
#   'championPoints': 6578,
#   'championPointsSinceLastLevel': 578,
#   'championPointsUntilNextLevel': 6022,
#   'chestGranted': False,
#   'lastPlayTime': 1586241904000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 6,
#   'championLevel': 3,
#   'championPoints': 6565,
#   'championPointsSinceLastLevel': 565,
#   'championPointsUntilNextLevel': 6035,
#   'chestGranted': False,
#   'lastPlayTime': 1584405618000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 102,
#   'championLevel': 2,
#   'championPoints': 5724,
#   'championPointsSinceLastLevel': 3924,
#   'championPointsUntilNextLevel': 276,
#   'chestGranted': False,
#   'lastPlayTime': 1579401364000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 111,
#   'championLevel': 2,
#   'championPoints': 5625,
#   'championPointsSinceLastLevel': 3825,
#   'championPointsUntilNextLevel': 375,
#   'chestGranted': True,
#   'lastPlayTime': 1580100783000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 54,
#   'championLevel': 2,
#   'championPoints': 5451,
#   'championPointsSinceLastLevel': 3651,
#   'championPointsUntilNextLevel': 549,
#   'chestGranted': False,
#   'lastPlayTime': 1586058443000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 119,
#   'championLevel': 2,
#   'championPoints': 5397,
#   'championPointsSinceLastLevel': 3597,
#   'championPointsUntilNextLevel': 603,
#   'chestGranted': False,
#   'lastPlayTime': 1575699876000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 117,
#   'championLevel': 2,
#   'championPoints': 5211,
#   'championPointsSinceLastLevel': 3411,
#   'championPointsUntilNextLevel': 789,
#   'chestGranted': False,
#   'lastPlayTime': 1577050535000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 9,
#   'championLevel': 2,
#   'championPoints': 5067,
#   'championPointsSinceLastLevel': 3267,
#   'championPointsUntilNextLevel': 933,
#   'chestGranted': False,
#   'lastPlayTime': 1585874585000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 68,
#   'championLevel': 2,
#   'championPoints': 5026,
#   'championPointsSinceLastLevel': 3226,
#   'championPointsUntilNextLevel': 974,
#   'chestGranted': False,
#   'lastPlayTime': 1578102857000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 223,
#   'championLevel': 2,
#   'championPoints': 4856,
#   'championPointsSinceLastLevel': 3056,
#   'championPointsUntilNextLevel': 1144,
#   'chestGranted': False,
#   'lastPlayTime': 1586050223000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 43,
#   'championLevel': 2,
#   'championPoints': 4829,
#   'championPointsSinceLastLevel': 3029,
#   'championPointsUntilNextLevel': 1171,
#   'chestGranted': False,
#   'lastPlayTime': 1580535975000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 45,
#   'championLevel': 2,
#   'championPoints': 4809,
#   'championPointsSinceLastLevel': 3009,
#   'championPointsUntilNextLevel': 1191,
#   'chestGranted': False,
#   'lastPlayTime': 1474777550000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 69,
#   'championLevel': 2,
#   'championPoints': 4768,
#   'championPointsSinceLastLevel': 2968,
#   'championPointsUntilNextLevel': 1232,
#   'chestGranted': True,
#   'lastPlayTime': 1580700448000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 55,
#   'championLevel': 2,
#   'championPoints': 4731,
#   'championPointsSinceLastLevel': 2931,
#   'championPointsUntilNextLevel': 1269,
#   'chestGranted': False,
#   'lastPlayTime': 1582961034000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 57,
#   'championLevel': 2,
#   'championPoints': 4239,
#   'championPointsSinceLastLevel': 2439,
#   'championPointsUntilNextLevel': 1761,
#   'chestGranted': False,
#   'lastPlayTime': 1586244247000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 30,
#   'championLevel': 2,
#   'championPoints': 4230,
#   'championPointsSinceLastLevel': 2430,
#   'championPointsUntilNextLevel': 1770,
#   'chestGranted': False,
#   'lastPlayTime': 1576820038000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 110,
#   'championLevel': 2,
#   'championPoints': 4094,
#   'championPointsSinceLastLevel': 2294,
#   'championPointsUntilNextLevel': 1906,
#   'chestGranted': False,
#   'lastPlayTime': 1489214926000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 127,
#   'championLevel': 2,
#   'championPoints': 4086,
#   'championPointsSinceLastLevel': 2286,
#   'championPointsUntilNextLevel': 1914,
#   'chestGranted': False,
#   'lastPlayTime': 1559357815000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 105,
#   'championLevel': 2,
#   'championPoints': 3983,
#   'championPointsSinceLastLevel': 2183,
#   'championPointsUntilNextLevel': 2017,
#   'chestGranted': False,
#   'lastPlayTime': 1579409997000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 555,
#   'championLevel': 2,
#   'championPoints': 3899,
#   'championPointsSinceLastLevel': 2099,
#   'championPointsUntilNextLevel': 2101,
#   'chestGranted': False,
#   'lastPlayTime': 1576212995000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 17,
#   'championLevel': 2,
#   'championPoints': 3829,
#   'championPointsSinceLastLevel': 2029,
#   'championPointsUntilNextLevel': 2171,
#   'chestGranted': False,
#   'lastPlayTime': 1580537332000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 245,
#   'championLevel': 2,
#   'championPoints': 3632,
#   'championPointsSinceLastLevel': 1832,
#   'championPointsUntilNextLevel': 2368,
#   'chestGranted': False,
#   'lastPlayTime': 1569890492000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 24,
#   'championLevel': 2,
#   'championPoints': 3631,
#   'championPointsSinceLastLevel': 1831,
#   'championPointsUntilNextLevel': 2369,
#   'chestGranted': False,
#   'lastPlayTime': 1579558535000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 134,
#   'championLevel': 2,
#   'championPoints': 3515,
#   'championPointsSinceLastLevel': 1715,
#   'championPointsUntilNextLevel': 2485,
#   'chestGranted': True,
#   'lastPlayTime': 1584138424000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 104,
#   'championLevel': 2,
#   'championPoints': 3219,
#   'championPointsSinceLastLevel': 1419,
#   'championPointsUntilNextLevel': 2781,
#   'chestGranted': False,
#   'lastPlayTime': 1566023299000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 350,
#   'championLevel': 2,
#   'championPoints': 3041,
#   'championPointsSinceLastLevel': 1241,
#   'championPointsUntilNextLevel': 2959,
#   'chestGranted': True,
#   'lastPlayTime': 1586238303000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 75,
#   'championLevel': 2,
#   'championPoints': 2887,
#   'championPointsSinceLastLevel': 1087,
#   'championPointsUntilNextLevel': 3113,
#   'chestGranted': False,
#   'lastPlayTime': 1579227805000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 82,
#   'championLevel': 2,
#   'championPoints': 2846,
#   'championPointsSinceLastLevel': 1046,
#   'championPointsUntilNextLevel': 3154,
#   'chestGranted': False,
#   'lastPlayTime': 1585433489000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 13,
#   'championLevel': 2,
#   'championPoints': 2694,
#   'championPointsSinceLastLevel': 894,
#   'championPointsUntilNextLevel': 3306,
#   'chestGranted': False,
#   'lastPlayTime': 1528841698000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 84,
#   'championLevel': 2,
#   'championPoints': 2602,
#   'championPointsSinceLastLevel': 802,
#   'championPointsUntilNextLevel': 3398,
#   'chestGranted': False,
#   'lastPlayTime': 1567824882000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 28,
#   'championLevel': 2,
#   'championPoints': 2568,
#   'championPointsSinceLastLevel': 768,
#   'championPointsUntilNextLevel': 3432,
#   'chestGranted': False,
#   'lastPlayTime': 1579139180000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 4,
#   'championLevel': 2,
#   'championPoints': 2335,
#   'championPointsSinceLastLevel': 535,
#   'championPointsUntilNextLevel': 3665,
#   'chestGranted': False,
#   'lastPlayTime': 1575087158000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 122,
#   'championLevel': 2,
#   'championPoints': 2279,
#   'championPointsSinceLastLevel': 479,
#   'championPointsUntilNextLevel': 3721,
#   'chestGranted': False,
#   'lastPlayTime': 1574048915000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 11,
#   'championLevel': 2,
#   'championPoints': 2213,
#   'championPointsSinceLastLevel': 413,
#   'championPointsUntilNextLevel': 3787,
#   'chestGranted': False,
#   'lastPlayTime': 1579509471000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 37,
#   'championLevel': 2,
#   'championPoints': 2054,
#   'championPointsSinceLastLevel': 254,
#   'championPointsUntilNextLevel': 3946,
#   'chestGranted': False,
#   'lastPlayTime': 1487657031000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 2,
#   'championLevel': 2,
#   'championPoints': 1932,
#   'championPointsSinceLastLevel': 132,
#   'championPointsUntilNextLevel': 4068,
#   'chestGranted': False,
#   'lastPlayTime': 1579411661000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 26,
#   'championLevel': 2,
#   'championPoints': 1922,
#   'championPointsSinceLastLevel': 122,
#   'championPointsUntilNextLevel': 4078,
#   'chestGranted': False,
#   'lastPlayTime': 1585345598000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 10,
#   'championLevel': 2,
#   'championPoints': 1896,
#   'championPointsSinceLastLevel': 96,
#   'championPointsUntilNextLevel': 4104,
#   'chestGranted': False,
#   'lastPlayTime': 1579222893000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 106,
#   'championLevel': 2,
#   'championPoints': 1877,
#   'championPointsSinceLastLevel': 77,
#   'championPointsUntilNextLevel': 4123,
#   'chestGranted': False,
#   'lastPlayTime': 1533785450000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 80,
#   'championLevel': 1,
#   'championPoints': 1795,
#   'championPointsSinceLastLevel': 1795,
#   'championPointsUntilNextLevel': 5,
#   'chestGranted': False,
#   'lastPlayTime': 1585430710000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 35,
#   'championLevel': 1,
#   'championPoints': 1785,
#   'championPointsSinceLastLevel': 1785,
#   'championPointsUntilNextLevel': 15,
#   'chestGranted': False,
#   'lastPlayTime': 1585871778000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 113,
#   'championLevel': 1,
#   'championPoints': 1700,
#   'championPointsSinceLastLevel': 1700,
#   'championPointsUntilNextLevel': 100,
#   'chestGranted': False,
#   'lastPlayTime': 1530334968000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 58,
#   'championLevel': 1,
#   'championPoints': 1654,
#   'championPointsSinceLastLevel': 1654,
#   'championPointsUntilNextLevel': 146,
#   'chestGranted': False,
#   'lastPlayTime': 1580696775000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 266,
#   'championLevel': 1,
#   'championPoints': 1568,
#   'championPointsSinceLastLevel': 1568,
#   'championPointsUntilNextLevel': 232,
#   'chestGranted': False,
#   'lastPlayTime': 1580357759000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 27,
#   'championLevel': 1,
#   'championPoints': 1497,
#   'championPointsSinceLastLevel': 1497,
#   'championPointsUntilNextLevel': 303,
#   'chestGranted': False,
#   'lastPlayTime': 1585443285000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 74,
#   'championLevel': 1,
#   'championPoints': 1473,
#   'championPointsSinceLastLevel': 1473,
#   'championPointsUntilNextLevel': 327,
#   'chestGranted': False,
#   'lastPlayTime': 1582413103000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 96,
#   'championLevel': 1,
#   'championPoints': 1266,
#   'championPointsSinceLastLevel': 1266,
#   'championPointsUntilNextLevel': 534,
#   'chestGranted': False,
#   'lastPlayTime': 1575692526000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 85,
#   'championLevel': 1,
#   'championPoints': 1200,
#   'championPointsSinceLastLevel': 1200,
#   'championPointsUntilNextLevel': 600,
#   'chestGranted': False,
#   'lastPlayTime': 1582355041000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 91,
#   'championLevel': 1,
#   'championPoints': 1137,
#   'championPointsSinceLastLevel': 1137,
#   'championPointsUntilNextLevel': 663,
#   'chestGranted': False,
#   'lastPlayTime': 1488863813000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 20,
#   'championLevel': 1,
#   'championPoints': 1136,
#   'championPointsSinceLastLevel': 1136,
#   'championPointsUntilNextLevel': 664,
#   'chestGranted': False,
#   'lastPlayTime': 1530687793000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 121,
#   'championLevel': 1,
#   'championPoints': 1133,
#   'championPointsSinceLastLevel': 1133,
#   'championPointsUntilNextLevel': 667,
#   'chestGranted': False,
#   'lastPlayTime': 1474853277000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 90,
#   'championLevel': 1,
#   'championPoints': 1084,
#   'championPointsSinceLastLevel': 1084,
#   'championPointsUntilNextLevel': 716,
#   'chestGranted': False,
#   'lastPlayTime': 1582436413000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 126,
#   'championLevel': 1,
#   'championPoints': 1009,
#   'championPointsSinceLastLevel': 1009,
#   'championPointsUntilNextLevel': 791,
#   'chestGranted': False,
#   'lastPlayTime': 1579513624000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 120,
#   'championLevel': 1,
#   'championPoints': 1004,
#   'championPointsSinceLastLevel': 1004,
#   'championPointsUntilNextLevel': 796,
#   'chestGranted': False,
#   'lastPlayTime': 1570307243000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 154,
#   'championLevel': 1,
#   'championPoints': 991,
#   'championPointsSinceLastLevel': 991,
#   'championPointsUntilNextLevel': 809,
#   'chestGranted': False,
#   'lastPlayTime': 1585380879000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 36,
#   'championLevel': 1,
#   'championPoints': 968,
#   'championPointsSinceLastLevel': 968,
#   'championPointsUntilNextLevel': 832,
#   'chestGranted': False,
#   'lastPlayTime': 1580539368000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 3,
#   'championLevel': 1,
#   'championPoints': 942,
#   'championPointsSinceLastLevel': 942,
#   'championPointsUntilNextLevel': 858,
#   'chestGranted': False,
#   'lastPlayTime': 1579143837000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 29,
#   'championLevel': 1,
#   'championPoints': 942,
#   'championPointsSinceLastLevel': 942,
#   'championPointsUntilNextLevel': 858,
#   'chestGranted': False,
#   'lastPlayTime': 1575681144000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 31,
#   'championLevel': 1,
#   'championPoints': 938,
#   'championPointsSinceLastLevel': 938,
#   'championPointsUntilNextLevel': 862,
#   'chestGranted': False,
#   'lastPlayTime': 1533689763000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 19,
#   'championLevel': 1,
#   'championPoints': 910,
#   'championPointsSinceLastLevel': 910,
#   'championPointsUntilNextLevel': 890,
#   'chestGranted': False,
#   'lastPlayTime': 1527447202000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 12,
#   'championLevel': 1,
#   'championPoints': 879,
#   'championPointsSinceLastLevel': 879,
#   'championPointsUntilNextLevel': 921,
#   'chestGranted': False,
#   'lastPlayTime': 1492750701000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 267,
#   'championLevel': 1,
#   'championPoints': 864,
#   'championPointsSinceLastLevel': 864,
#   'championPointsUntilNextLevel': 936,
#   'chestGranted': False,
#   'lastPlayTime': 1585878852000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 875,
#   'championLevel': 1,
#   'championPoints': 862,
#   'championPointsSinceLastLevel': 862,
#   'championPointsUntilNextLevel': 938,
#   'chestGranted': False,
#   'lastPlayTime': 1586056554000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 98,
#   'championLevel': 1,
#   'championPoints': 824,
#   'championPointsSinceLastLevel': 824,
#   'championPointsUntilNextLevel': 976,
#   'chestGranted': False,
#   'lastPlayTime': 1585349145000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 268,
#   'championLevel': 1,
#   'championPoints': 605,
#   'championPointsSinceLastLevel': 605,
#   'championPointsUntilNextLevel': 1195,
#   'chestGranted': False,
#   'lastPlayTime': 1491820955000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 136,
#   'championLevel': 1,
#   'championPoints': 548,
#   'championPointsSinceLastLevel': 548,
#   'championPointsUntilNextLevel': 1252,
#   'chestGranted': False,
#   'lastPlayTime': 1580104399000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 23,
#   'championLevel': 1,
#   'championPoints': 469,
#   'championPointsSinceLastLevel': 469,
#   'championPointsUntilNextLevel': 1331,
#   'chestGranted': False,
#   'lastPlayTime': 1462766697000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 101,
#   'championLevel': 1,
#   'championPoints': 459,
#   'championPointsSinceLastLevel': 459,
#   'championPointsUntilNextLevel': 1341,
#   'chestGranted': False,
#   'lastPlayTime': 1585435724000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 60,
#   'championLevel': 1,
#   'championPoints': 438,
#   'championPointsSinceLastLevel': 438,
#   'championPointsUntilNextLevel': 1362,
#   'chestGranted': False,
#   'lastPlayTime': 1557225098000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 61,
#   'championLevel': 1,
#   'championPoints': 381,
#   'championPointsSinceLastLevel': 381,
#   'championPointsUntilNextLevel': 1419,
#   'chestGranted': False,
#   'lastPlayTime': 1559227089000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 41,
#   'championLevel': 1,
#   'championPoints': 324,
#   'championPointsSinceLastLevel': 324,
#   'championPointsUntilNextLevel': 1476,
#   'chestGranted': False,
#   'lastPlayTime': 1499394471000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 78,
#   'championLevel': 1,
#   'championPoints': 298,
#   'championPointsSinceLastLevel': 298,
#   'championPointsUntilNextLevel': 1502,
#   'chestGranted': False,
#   'lastPlayTime': 1527448762000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 143,
#   'championLevel': 1,
#   'championPoints': 297,
#   'championPointsSinceLastLevel': 297,
#   'championPointsUntilNextLevel': 1503,
#   'chestGranted': True,
#   'lastPlayTime': 1579135923000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 32,
#   'championLevel': 1,
#   'championPoints': 284,
#   'championPointsSinceLastLevel': 284,
#   'championPointsUntilNextLevel': 1516,
#   'chestGranted': False,
#   'lastPlayTime': 1527457112000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 38,
#   'championLevel': 1,
#   'championPoints': 230,
#   'championPointsSinceLastLevel': 230,
#   'championPointsUntilNextLevel': 1570,
#   'chestGranted': False,
#   'lastPlayTime': 1560893037000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 42,
#   'championLevel': 1,
#   'championPoints': 207,
#   'championPointsSinceLastLevel': 207,
#   'championPointsUntilNextLevel': 1593,
#   'chestGranted': False,
#   'lastPlayTime': 1440738627000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 40,
#   'championLevel': 1,
#   'championPoints': 189,
#   'championPointsSinceLastLevel': 189,
#   'championPointsUntilNextLevel': 1611,
#   'chestGranted': False,
#   'lastPlayTime': 1462768909000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 246,
#   'championLevel': 1,
#   'championPoints': 187,
#   'championPointsSinceLastLevel': 187,
#   'championPointsUntilNextLevel': 1613,
#   'chestGranted': False,
#   'lastPlayTime': 1564284818000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 44,
#   'championLevel': 1,
#   'championPoints': 163,
#   'championPointsSinceLastLevel': 163,
#   'championPointsUntilNextLevel': 1637,
#   'chestGranted': False,
#   'lastPlayTime': 1567828747000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 254,
#   'championLevel': 1,
#   'championPoints': 125,
#   'championPointsSinceLastLevel': 125,
#   'championPointsUntilNextLevel': 1675,
#   'chestGranted': False,
#   'lastPlayTime': 1549007358000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 50,
#   'championLevel': 1,
#   'championPoints': 122,
#   'championPointsSinceLastLevel': 122,
#   'championPointsUntilNextLevel': 1678,
#   'chestGranted': False,
#   'lastPlayTime': 1574402848000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 141,
#   'championLevel': 1,
#   'championPoints': 119,
#   'championPointsSinceLastLevel': 119,
#   'championPointsUntilNextLevel': 1681,
#   'chestGranted': False,
#   'lastPlayTime': 1530517744000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0},
#  {'championId': 517,
#   'championLevel': 1,
#   'championPoints': 105,
#   'championPointsSinceLastLevel': 105,
#   'championPointsUntilNextLevel': 1695,
#   'chestGranted': False,
#   'lastPlayTime': 1579677007000,
#   'summonerId': 'a-Q-p5kn8DJm8QNGr3Jf-Rnszxv5sjw0lr_AMFT9T0A3ofU',
#   'tokensEarned': 0}]

# %%
champion = []
championLevel = []

for i in range(len(championMastery)):
    champion.append(championMastery[i]['championId'])
    championLevel.append(championMastery[i]['championLevel'])
    
champion_dict = {
    'Champion' : champion,
    'Champion Mastery Level' : championLevel
}    

championMastery_df = pd.DataFrame(data = champion_dict)
championMastery_df
# Out:
#      Champion  Champion Mastery Level
# 0         222                       7
# 1         412                       7
# 2         236                       7
# 3          51                       6
# 4         103                       6
# ..        ...                     ...
# 119        44                       1
# 120       254                       1
# 121        50                       1
# 122       141                       1
# 123       517                       1
#
# [124 rows x 2 columns]
